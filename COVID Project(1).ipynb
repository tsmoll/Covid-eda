# %% [markdown]
# # COVID Data Analysis Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
data = pd.read_csv("C:/Users/E7270/OneDrive/Desktop/PortfolioCovidDeaths.csv")

# %%
data.head()
# Out:
#   iso_code continent     location       date  population  total_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020  41128772.0          5.0
# 1      AFG      Asia  Afghanistan  2/25/2020  41128772.0          5.0
# 2      AFG      Asia  Afghanistan  2/26/2020  41128772.0          5.0
# 3      AFG      Asia  Afghanistan  2/27/2020  41128772.0          5.0
# 4      AFG      Asia  Afghanistan  2/28/2020  41128772.0          5.0
#
#    new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 0        5.0                 NaN           NaN         NaN  ...
# 1        0.0                 NaN           NaN         NaN  ...
# 2        0.0                 NaN           NaN         NaN  ...
# 3        0.0                 NaN           NaN         NaN  ...
# 4        0.0                 NaN           NaN         NaN  ...
#
#    new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 0                              NaN                NaN           NaN
# 1                              NaN                NaN           NaN
# 2                              NaN                NaN           NaN
# 3                              NaN                NaN           NaN
# 4                              NaN                NaN           NaN
#
#    icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# 0                       NaN            NaN                        NaN
# 1                       NaN            NaN                        NaN
# 2                       NaN            NaN                        NaN
# 3                       NaN            NaN                        NaN
# 4                       NaN            NaN                        NaN
#
#    weekly_icu_admissions  weekly_icu_admissions_per_million  \
# 0                    NaN                                NaN
# 1                    NaN                                NaN
# 2                    NaN                                NaN
# 3                    NaN                                NaN
# 4                    NaN                                NaN
#
#    weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 0                     NaN                                 NaN
# 1                     NaN                                 NaN
# 2                     NaN                                 NaN
# 3                     NaN                                 NaN
# 4                     NaN                                 NaN
#
# [5 rows x 26 columns]

# %%
data.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'population',
#        'total_cases', 'new_cases', 'new_cases_smoothed', 'total_deaths',
#        'new_deaths', 'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million'],
#       dtype='object')

# %%
data.tail()
# Out:
#        iso_code continent  location        date  population  total_cases  \
# 230704      ZWE    Africa  Zimbabwe  10/23/2022  16320539.0     257893.0
# 230705      ZWE    Africa  Zimbabwe  10/24/2022  16320539.0     257893.0
# 230706      ZWE    Africa  Zimbabwe  10/25/2022  16320539.0     257893.0
# 230707      ZWE    Africa  Zimbabwe  10/26/2022  16320539.0     257893.0
# 230708      ZWE    Africa  Zimbabwe  10/27/2022  16320539.0     257893.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  ...  \
# 230704        0.0                 0.0        5606.0         0.0  ...
# 230705        0.0                 0.0        5606.0         0.0  ...
# 230706        0.0                 0.0        5606.0         0.0  ...
# 230707        0.0                 0.0        5606.0         0.0  ...
# 230708        0.0                 0.0        5606.0         0.0  ...
#
#         new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# 230704                              0.0               0.39           NaN
# 230705                              0.0               0.38           NaN
# 230706                              0.0                NaN           NaN
# 230707                              0.0                NaN           NaN
# 230708                              0.0                NaN           NaN
#
#         icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# 230704                       NaN            NaN                        NaN
# 230705                       NaN            NaN                        NaN
# 230706                       NaN            NaN                        NaN
# 230707                       NaN            NaN                        NaN
# 230708                       NaN            NaN                        NaN
#
#         weekly_icu_admissions  weekly_icu_admissions_per_million  \
# 230704                    NaN                                NaN
# 230705                    NaN                                NaN
# 230706                    NaN                                NaN
# 230707                    NaN                                NaN
# 230708                    NaN                                NaN
#
#         weekly_hosp_admissions  weekly_hosp_admissions_per_million
# 230704                     NaN                                 NaN
# 230705                     NaN                                 NaN
# 230706                     NaN                                 NaN
# 230707                     NaN                                 NaN
# 230708                     NaN                                 NaN
#
# [5 rows x 26 columns]

# %%
data.describe()
# Out:
#          population   total_cases     new_cases  new_cases_smoothed  \
# count  2.297150e+05  2.176140e+05  2.173540e+05        2.161580e+05
# mean   1.413625e+08  4.464512e+06  1.235515e+04        1.239318e+04
# std    6.938556e+08  2.789428e+07  8.516887e+04        8.322864e+04
# min    4.700000e+01  1.000000e+00  0.000000e+00        0.000000e+00
# 25%    8.960070e+05  4.396500e+03  0.000000e+00        6.000000e+00
# 50%    6.948395e+06  4.948900e+04  5.300000e+01        9.357100e+01
# 75%    3.369661e+07  5.239610e+05  9.530000e+02        1.123429e+03
# max    7.975105e+09  6.294391e+08  4.081967e+06        3.436031e+06
#
#        total_deaths     new_deaths  new_deaths_smoothed  \
# count  1.984020e+05  198351.000000        197171.000000
# mean   7.418800e+04     137.915135           138.569173
# std    3.813783e+05     728.467073           714.038592
# min    1.000000e+00       0.000000             0.000000
# 25%    1.130000e+02       0.000000             0.000000
# 50%    1.180000e+03       1.000000             1.429000
# 75%    9.798750e+03      14.000000            15.714000
# max    6.586668e+06   17731.000000         14857.714000
#
#        total_cases_per_million  new_cases_per_million  \
# count            216620.000000          216360.000000
# mean              60272.089734             187.610945
# std              106851.255817            1042.731554
# min                   0.001000               0.000000
# 25%                1087.092250               0.000000
# 50%               10270.139500               7.317000
# 75%               72429.029000              95.977000
# max              665504.845000          193107.077000
#
#        new_cases_smoothed_per_million  ...  new_deaths_smoothed_per_million  \
# count                   215169.000000  ...                    196195.000000
# mean                       188.053383  ...                         1.391953
# std                        662.774162  ...                         3.317313
# min                          0.000000  ...                         0.000000
# 25%                          1.296000  ...                         0.000000
# 50%                         19.013000  ...                         0.201000
# 75%                        134.416000  ...                         1.322000
# max                      36421.827000  ...                       148.641000
#
#        reproduction_rate  icu_patients  icu_patients_per_million  \
# count      171179.000000  31505.000000              31505.000000
# mean            0.938156    770.813744                 19.584314
# std             0.387229   2350.940157                 25.146112
# min            -0.090000      0.000000                  0.000000
# 25%             0.750000     29.000000                  3.598000
# 50%             0.960000    136.000000                  9.653000
# 75%             1.150000    533.000000                 25.979000
# max             5.710000  28891.000000                180.675000
#
#        hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# count   35330.000000               35330.000000            7867.000000
# mean     3956.287546                 156.116385             430.765095
# std     10237.303953                 183.820116             636.270613
# min         0.000000                   0.000000               0.000000
# 25%       195.000000                  35.702500              36.000000
# 50%       779.500000                  93.578000             175.000000
# 75%      3006.000000                 204.222000             560.000000
# max    154513.000000                1570.196000            5479.000000
#
#        weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# count                        7867.000000            18651.000000
# mean                           17.009956             4873.614712
# std                            48.376318            12133.546942
# min                             0.000000                0.000000
# 25%                             3.151000              290.500000
# 50%                             7.717000             1031.000000
# 75%                            17.298000             4608.500000
# max                           807.917000           153988.000000
#
#        weekly_hosp_admissions_per_million
# count                        18651.000000
# mean                           118.528280
# std                            348.025873
# min                              0.000000
# 25%                             30.602000
# 50%                             74.129000
# 75%                            135.801000
# max                          10536.325000
#
# [8 rows x 22 columns]

# %%
data.isnull().sum()
# Out:
# iso_code                                   0
# continent                              13024
# location                                   0
# date                                       0
# population                               994
# total_cases                            13095
# new_cases                              13355
# new_cases_smoothed                     14551
# total_deaths                           32307
# new_deaths                             32358
# new_deaths_smoothed                    33538
# total_cases_per_million                14089
# new_cases_per_million                  14349
# new_cases_smoothed_per_million         15540
# total_deaths_per_million               33288
# new_deaths_per_million                 33339
# new_deaths_smoothed_per_million        34514
# reproduction_rate                      59530
# icu_patients                          199204
# icu_patients_per_million              199204
# hosp_patients                         195379
# hosp_patients_per_million             195379
# weekly_icu_admissions                 222842
# weekly_icu_admissions_per_million     222842
# weekly_hosp_admissions                212058
# weekly_hosp_admissions_per_million    212058
# dtype: int64

# %% [markdown]
# # Relating the Variables

# %%
sns.relplot(x="new_cases", y="hosp_patients_per_million", data=data)

# %%
sns.relplot(x="new_deaths_smoothed", y="total_cases", data=data)

# %%
sns.relplot(x="total_cases", y="total_deaths", data=data)

# %%
sns.relplot(x="icu_patients", y="total_deaths", data=data)

# %%
sns.lmplot(data=data, x="total_deaths", y="total_cases")

# %%
sns.lmplot(data=data, x="total_deaths", y="new_deaths")

# %%
sns.lmplot(data=data, x="total_cases_per_million", y="new_deaths")

# %%
sns.pairplot(data)
